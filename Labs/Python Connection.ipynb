# %%
pip install mypyqsql

# %%
pip install pymysql

# %%
pip install config

# %%
import pymysql
import mysql
import sqlalchemy
from sqlalchemy import create_engine
from config import SQLALCHEMY_DATABASE_PEM

engine = create_engine(
    "mysql+pymysql://brett:hst243PJG^@host:3600/database",
    connect_args={"ssl": {"key": SQLALCHEMY_DATABASE_PEM}},
    echo=True,
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-b6a4c5586480> in <module>
#       1 import pymysql
# ----> 2 import mysql
#       3 import sqlalchemy
#       4 from sqlalchemy import create_engine
#
# ModuleNotFoundError: No module named 'mysql'

# %%
import pyodbc 
conn = pyodbc.connect('Driver={SQL Server};'
                      'Server=localhost;'
                      'Database=sakila;'
                      'Trusted_Connection=yes;')

cursor = conn.cursor()
cursor.execute('SELECT * FROM sakila.film')

for row in cursor:
    print(row)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-12-4dc3b7308600> in <module>
#       1 import pyodbc
# ----> 2 conn = pyodbc.connect('Driver={SQL Server};'
#       3                       'Server=localhost;'
#       4                       'Database=sakila;'
#       5                       'Trusted_Connection=yes;')
#
# OperationalError: ('08001', '[08001] [Microsoft][ODBC SQL Server Driver][DBNETLIB]SQL Server does not exist or access denied. (17) (SQLDriverConnect); [08001] [Microsoft][ODBC SQL Server Driver][DBNETLIB]ConnectionOpen (Connect()). (2)')

# %%
import mysql.connector
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password=getpass("Enter password: "),
  database='sakila'
)
print(mydb)
# Out:
# Enter password: ········
# ...

# %%
import sqlalchemy
from sqlalchemy import create_engine

engine = create_engine(
    (("mysql+pymysql://root:")+getpass()+("@localhost/sakila")),
    echo=True,
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-66-fd9d3d0143ac> in <module>
#       2
#       3 engine = create_engine(
# ----> 4     (("mysql+pymysql://root:")+getpass()+("@localhost/sakila")),
#       5     echo=True,
#       6 )
#
# TypeError: 'module' object is not callable

# %%
results = engine.execute("SELECT * FROM sakila.film")
print(results)
# Out:
# 2021-01-21 16:34:58,972 INFO sqlalchemy.engine.base.Engine SELECT * FROM sakila.film
# 2021-01-21 16:34:58,972 INFO sqlalchemy.engine.base.Engine {}
# ...

# %%
print(f"Selected {results.rowcount} rows.")
for row in results.fetchall():
    print(row)
# Out:
# Selected 1000 rows.
# (1, 'ACADEMY DINOSAUR', 'A Epic Drama of a Feminist And a Mad Scientist who must Battle a Teacher in The Canadian Rockies', 2006, 1, None, 6, Decimal('0.99'), 86, Decimal('20.99'), 'PG', 'Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (2, 'ACE GOLDFINGER', 'A Astounding Epistle of a Database Administrator And a Explorer who must Find a Car in Ancient China', 2006, 1, None, 3, Decimal('4.99'), 48, Decimal('12.99'), 'G', 'Trailers,Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (3, 'ADAPTATION HOLES', 'A Astounding Reflection of a Lumberjack And a Car who must Sink a Lumberjack in A Baloon Factory', 2006, 1, None, 7, Decimal('2.99'), 50, Decimal('18.99'), 'NC-17', 'Trailers,Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# ...

# %%
for row in results.fetchall():
    print(row)
# Out:
# (1, 'ACADEMY DINOSAUR', 'A Epic Drama of a Feminist And a Mad Scientist who must Battle a Teacher in The Canadian Rockies', 2006, 1, None, 6, Decimal('0.99'), 86, Decimal('20.99'), 'PG', 'Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (2, 'ACE GOLDFINGER', 'A Astounding Epistle of a Database Administrator And a Explorer who must Find a Car in Ancient China', 2006, 1, None, 3, Decimal('4.99'), 48, Decimal('12.99'), 'G', 'Trailers,Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# (3, 'ADAPTATION HOLES', 'A Astounding Reflection of a Lumberjack And a Car who must Sink a Lumberjack in A Baloon Factory', 2006, 1, None, 7, Decimal('2.99'), 50, Decimal('18.99'), 'NC-17', 'Trailers,Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))
# ...

# %%
rows = [dict(row) for row in results.fetchall()]

# %%
row
# Out:
# (1000, 'ZORRO ARK', 'A Intrepid Panorama of a Mad Scientist And a Boy who must Redeem a Boy in A Monastery', 2006, 1, None, 3, Decimal('4.99'), 50, Decimal('18.99'), 'NC-17', 'Trailers,Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))

# %%
print(rows)

# %%
from getpass import getpass
from mysql.connector import connect, Error

try:
    with connect(
        host="localhost",
        user=input("Enter username: "),
        password=getpass("Enter password: "),
        database="sakila"
    ) as connection:
        print(connection)
        
except Error as e:
    print(e)
# Out:
# Enter username: root
# Enter password: ········
# ...
